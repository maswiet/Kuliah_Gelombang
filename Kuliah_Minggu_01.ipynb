# %% [markdown]
# # Tentang Osilasi
#
#
#
# Marilah kita mengulang kembali materi tentang osilasi, yang telah diperoleh sewaktu di sekolah menengah serta saat mengambil materi Fisika Dasar 2 yang menjadi prasyarat matakuliah Gelombang ini. Materi yang diberikan dalam kuliah ini mengikuti isi dari buku Akira-Hirose, sehingga penjelasan yang lebih detil, saya mohon untuk menelaah keseluruhan isi dari buku tersebut. Agar pemahaman menjadi lebih komplit, atau bahasa jawanya *tutug* alias tuntas silahkan membaca-baca buku HJ Pain, yang dapat dicari versi pdf-nya melalui internet. O, iya buku Gelombang karangan Akira Hirose tersedia di perpustakaan, namun yang edisi pertama. Isinya sama dengan edisi kedua yang lebih baru, jadi tidak perlu kuatir.
#
# ## Isi perkuliahan
# - Pendahuluan
# - Sistem pegas massa
# - Energi yang dilontarkan selama osilasi mekanik
# - Sistem osilasi mekanik yang lain
# - Osilasi elektromagnetik
# - Osilasi teredam
# - Osilasi Terpaksa
# - Contoh soal latihan
# <div class="alert alert-info" style="font-size:12pt; margin-top:20px"> **Obyektif** atau bahasa resminya ***Learning outcome***  dari kuliah ini tidak terlalu muluk-muluk, hanya mengulang konsep tentang osilasi, melalui contoh yang paling sederhana yaitu sistem pegas dengan massa. Gelombang elektromagnetik diperkenalkan dengan sistem elektronik berupa rangkaian R-L-C, Resistor, Induktor dan Kapasitor. Selain itu mulai diperkenalkan sistem getaran teredam dan terpaksa. Diharapkan dari kuliah perdana ini, mahasiswa siap diajak menapak untuk mulai pendakian gunung,<del>sehingga nanti dapat menjadi merasa lebih ringan saat lereng mulai semakin terjal, saat melalui lembah fisika kuantum di jalur pendakian fisika maupun lembah seismologi dan metode seismik di jalur pendakian geofisika</del>.
# </div>
#
# ## Pendahuluan
#
# ![Tsunami](https://upload.wikimedia.org/wikipedia/commons/thumb/a/a5/Tsunami_by_hokusai_19th_century.jpg/320px-Tsunami_by_hokusai_19th_century.jpg)
#
# Saya masih ingat betul definisi gelombang yang diajarkan saat saya sekolah menengah, yaitu getaran yang merambat. Sementara defini getaran itu sendiripun saya juga ingat, yaitu gerak bolak balik di sekitar titik tertentu. Fenomena gelombang secara tidak sadari telah menjadi bagian di dalam kehidupan kita. Jadi, belajar gelombang, sejatinya adalah mengamati apa yang ada di sekitar kita, kemudian berusaha mengamati fenomena tersebut secara kuantitatif. Gelombang air di pantai, gelombang tali, Tsunami, gelombang suara, gelombang yang membawa sinyal handphone (gelombang elektromagnetik), gelombang gempabumi adalah contoh-contoh fenomena gelombang yang sering kita lihat.
#
# Gelombang terjadi karena ada sesuatu (sumber) yang bergetar atau karena ada usikan. Dan ini berlau umum, bahkan dalam fenomena sosial, misalnya ada usikan didalam lingkungan masyarakat, misal berupa kebijakan yang tidak populer, maka akan timbul gelombang protes dari masyarakat ... ^_^ Just a joke!
#
# Berikutnya, akan sangat membantu kalau kita dapat mengingat kembali konsep dasar matematik, diantaranya mengenai fungsi-fungsi trigonometri dan turunannya seperti
#
# <center>$\frac{d}{dx} \sin ax = a \cos ax$, $ \frac{d}{dx} \cos ax = -a \sin ax $, </center>
#
# karena fungsi ini adalah basis dari kuantifikasi gelombang dilakukan.
#
# ## Sistem Pegas Massa
#
# Mejadi dosen jaman now, terasa lebih mudah karena semua materi ajar pastinya sudah ada *somewhere* di awan (*cloud*). Misal materi kuliah hari ini, dengan gamblang dijelaskan pada link berikut [Osilasi Harmonik](https://en.wikipedia.org/wiki/Harmonic_oscillator), yang menempati urutan atas Google. Wikipedia (berbahasa Inggris) sangat baik untuk belajar, namun JANGAN digunakan untuk referensi Skripsi/Thesis !! Nah, sekarang silahkan dipelajari materi dari sumber pada link di atas tadi. Masalah bahasa saat ini bukan menjadi kendala, karena kalau Anda memakai [Chrome](https://www.google.com/chrome/), disana ada fasilitas untuk menerjemahkan menjadi bahasa Indonesia. Andaikan membaca saja masih berat, carilah aplikasi text-to-voice untuk membacakan naskah tersebut, jadi kita tinggal mendengarkan saja, seolah-olah sedang diberi kuliah he he he. Misalnya aplikasi [ini](https://responsivevoice.com/) dapat diperintah untuk membacakan teks dalam berbagai bahasa, termasuk bahasa Indonesia dalam bentuk suara.
#
# Materi presentasi untuk belajar dalam bentuk Power Point (yang telah di-pdfkan) juga dapat dilihat pada [tautan ini](http://users.physics.harvard.edu/~morii/phys15c/2002/lectures/Lecture01.pdf). Silahkan dibuka-buka slide tersebut untuk belajar mandiri, saya akan menjelaskan sisi lainnya, yaitu penggunaan aplikasi komputer (dalam memecahkan masalah mendasar dari gelombang).
#
# ## Model Fisika - Visualisasi
# Pada kesempatan ini, akan ditunjukkan bagaimana aplikasi komputer dapat membantu memahami masalah dalam hal gelombang sederhana. Ada 2 hal penting dalam pekerjaan di fisika, yaitu bagaimana fenomena dimodelkan secara fisika (dengan persamaan matematika) dan bagaimana men-visualisasikan persamaan tersebut, sehingga kita faham fenomenanya. Aplikasi komputer jaman sekarang juga telah didesain untuk mudah digunakan. Misalnya [Python](https://www.python.org/). Saya berikan contoh yang sederhana untuk melakukan 2 hal tersebut agar dapat dipakai sebagai bekal memahami bagian 1 dari kuliah Gelombang ini.
#
# Dari yang ke 2 dulu, ya, yaitu memodelkan fenomena secara visual atau grafis dengan Python. Untuk itu, perlu diinstall dahulu program Python, numpy dan matplotlib terlebih dahulu. Kemudian [installah](http://jupyter.org/install) Jupyter notebook agar dapat mengedit modul ini serta menuliskan program Python secara interaktif.

# %%
print 2 * 8
print 5.0 / 2.0
print 1 + 1
# Out:
# 16
# 2.5
# 2

# %% [markdown]
# Jadi, melakukan operasi perkalian, penjumlahan dan pembagian semudah menggunakan kalkulator. Sekarang bagaimana dengan fungsi trigonometri yang menjadi sebuah fungsi andalan saat berhubungan dengan masalah gelombang? Mudah saja, tetap sama seperti menggunakan kalkulator. Hanya perlu kita panggil dahulu modul matematika bernama **math** yang dipanggil dengan perintah **import

# %%
import math
print sin(pi/2.)
# Out:
# 1

# %% [markdown]
# Seperti kalkulator, sudut yang dimasukkan dalam operasi sinus adalah sudut dalam radian, jadi sudut derajat harus dikali dengan $\frac{\pi}{180}$

# %% [markdown]
# untuk menggambar juga mudah, kita hanya perlu perintah **plot**, namun memerlukan modul matplotlib dulu, seperti contoh berikut:
# Gambarkan grafik fungsi sinus dengan frekuensi 1 Hz selama 10 detik, dengan amplitudo 2 satuan. Maka persamaannya adalah
#
# <center>$f = A \times \sin 2 \pi f t = 2 \times \sin 2 \pi t, t = 1..10$</center>
#
# Untuk membuat vektor waktu, $t$, diperlukan modul numpy (numerical Python), yang harus diimport terlebih dahulu

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0,10,0.05)
f = 2 * np.sin(2*math.pi*1*t)
plt.plot(t,f)
plt.xlabel('waktu[dt]')
plt.ylabel('Amplitudo')
plt.show()

# %% [markdown]
# Seperti definisi frekuensi, maka dalam 10 detik, sinyal 1 Hz akan terdiri atas sepuluh gelombang. Perhatikan apa yang terjadi saat frekuensinya jadi 0,5 Hz.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0,10,0.05)
f = 2 * np.sin(2*math.pi*0.5*t)
plt.plot(t,f)
plt.xlabel('waktu[dt]')
plt.ylabel('Amplitudo')
plt.show()

# %% [markdown]
# Saya harapkan dengan modal pengetahuan ini, secara kreatif kalian dapat mengembangkan imajinasi anda terhadap visualisasi gelombang semaunya ..

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0,20,0.05)
f = 2 * np.sin(2*math.pi*0.5*t) + 2 * np.cos(2*math.pi*0.75*t) 
plt.plot(t,f,'red')
plt.xlabel('waktu[dt]')
plt.ylabel('Amplitudo')
plt.grid()
plt.show()

# %% [markdown]
# Sekarang akan saya jelaskan sebuah ilmu yang dapat membantu memecahkan masalah difisika, tentu dengan tanpa masalah, seperti moto pegadaian.
#
# ![Pegadaian](https://sumatfeet.files.wordpress.com/2012/11/img_2217.jpg)
#
# Namun mohon berhati-hati dengan ilmu ini dalam pemakaiannya. Aplikasi paling sakti dalam masalah ini sebenarnya adalah Wolfram [Matematica](https://www.wolfram.com/mathematica/), namun hampir semua aplikasi seperti Matlab atau Python juga dibekali sebagian dari kesaktian Wolfram, yaitu symbolic mathematics, atau matematika dengan simbol. Jadi gampangnya begini. Andaikan ada pertanyaan, bagaiman solusi dari persamaan gelombang pada pegas dengan konstanta $k$ yang diberi massa seberat $m$ yang disimpangkan dengan simpangan sebesar x,
# <center>$\frac{d^2x}{dt^2}+\frac{k}{m}x=0$</center>
#
# artinya kita diminta mencari berapa simpangan sebagai fungsi waktu, $x(t)$ . *Piye, hayo?*

# %% [markdown]
# Terima kasih kepada komunitas Python yang mengembangkan modul untuk matematika simbol, yaitu [sympy](https://www.sympy.org/en/index.html). Di bawah ini saya contohkan bagaimana symbolic math di dalam Python beraksi untuk menghitung diferensial dari fungsi,

# %%
from sympy import *
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
diff(cos(x)+sin(x),x)
# Out:
# -sin(x) + cos(x)

# %% [markdown]
# Bagaimana kalau permasalahan integrasi? Saya beri contoh, ya? Perintahnya adalah **Integral**.

# %%
integ = Integral((x**4 + x**2*exp(x) - x**2 - 2*x*exp(x) - 2*x -
...     exp(x))*exp(x)/((x - 1)**2*(x + 1)**2*(exp(x) + 1)), x)
integ
# Out:
# ⌠
# ⎮ ⎛ 4    2  x    2        x          x⎞  x
# ⎮ ⎝x  + x ⋅ℯ  - x  - 2⋅x⋅ℯ  - 2⋅x - ℯ ⎠⋅ℯ
# ⎮ ──────────────────────────────────────── dx
# ⎮               2        2 ⎛ x    ⎞
# ⎮        (x - 1) ⋅(x + 1) ⋅⎝ℯ  + 1⎠
# ⌡

# %% [markdown]
# Untuk memerintah Python menghitung integral tak-tentu tersebut, lakukan dengan perintah **integ.doit()

# %%
integ.doit()
# Out:
#                  x
#    ⎛ x    ⎞     ℯ
# log⎝ℯ  + 1⎠ + ──────
#                2
#               x  - 1

# %% [markdown]
# Keren, bukan?

# %% [markdown]
# Hayo, sekarang asah kreatifitas kalian dengan mencoba memecahkan persamaan gelombang diatas tadi. Agak sulit memang, namun cobalah peras seluruh kemampuan yang ada. Mungkin perlu membaca sedikit tentang sympy *documentation* pada website sympy tadi. Coba, ya minggu depan kalau masih belum dapat jawaban kita akan bahas bersama. Kuncinya adalah Sabar. Jadi, jadikanlah sabar sebagai penolongmu.
#
# Ingatlah cerita Kenji
