# %% [markdown]
# ## Aplikasi Gelombang EM dalam keseharian
#
# Berkembangnya teknologi berbasis IoT dan sistem nirkabel (wireless) saat ini didukung oleh semakin canggihnya perangkat elektronika, sehingga perangkat pembangkit dan penerima sinyal EM semakin kecil dan praktis untuk "dioprek"

# %% [markdown]
# Dalam banyak aplikasi, pemakaian gelombang radio saat ini menjadi salah satu yang berkembang pesat, salah satunya dengan teknologi LoRa
#
# ![](https://www.sphinxcomputer.de/Download/LoRa/LoRa.jpg)

# %% [markdown]
# ![](https://www.microchip.com/images/default-source/design-centers/data-and-video-transceivers/lorasolution.jpg?sfvrsn=2b30c606_3)

# %% [markdown]
# ## Gelombang EM
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/EM-Wave-18f26063f4a2ec842f149d6c732e296bba35a172d72c0392a88789273de91527.gif)

# %% [markdown]
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/freq_bands-06cdeca222bf0c62d46c5798a7270ab8cac2f87d846aae909b258163cb0c8890.png)

# %% [markdown]
# ### Jangkau operasional dan battery life
#
# ![](https://simpan.ugm.ac.id/index.php/apps/files_sharing/ajax/publicpreview.php?x=1920&y=619&a=true&file=lora.png&t=77qxicfOOvcTiIL&scalingup=0)

# %% [markdown]
# ### Modulasi sinyal
#
# Memanfaatkan karakteristik gelombang yaitu frekuensi, amplitudo dan fase, informasi (sinyal) dapat dikirimkan melalui gelombang EM, dengan cara di"campur" atau dimodulasi dengan pembawa (carrier).
#
# AM
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/AM-4e4155cd0e92d2806e7b55b1af065587f688eaa1ae1b6be6e45af75e476125e9.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt

modulator_frequency = 4.0
carrier_frequency = 40.0
modulation_index = 1.0

time = np.arange(44100.0) / 44100.0
modulator = np.sin(2.0 * np.pi * modulator_frequency * time) * modulation_index
carrier = np.sin(2.0 * np.pi * carrier_frequency * time)
product = np.zeros_like(modulator)

for i, t in enumerate(time):
    product[i] = np.sin(2. * np.pi * (carrier_frequency * t + modulator[i]))

plt.subplot(3, 1, 1)
plt.title('Frequency Modulation')
plt.plot(modulator)
plt.ylabel('Amplitude')
plt.xlabel('Modulator signal')
plt.subplot(3, 1, 2)
plt.plot(carrier)
plt.ylabel('Amplitude')
plt.xlabel('Carrier signal')
plt.subplot(3, 1, 3)
plt.plot(product)
plt.ylabel('Amplitude')
plt.xlabel('Output signal')
plt.show()

# %% [markdown]
# FM
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/FM-41b94710b40651603229e8fac1dc360a5229732b95ab13c606c189c9dccceaad.jpg)

# %% [markdown]
# PM (Phase Modulation)
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/PM-002f3fb7c734f5f2f9ce984ba152807d88722340eb081de77e7c4fe4c2769400.jpg)

# %% [markdown]
# ### Modulasi Digital
#
# Ada 3 jenis yang paling utama, Amplitude Shift Keying, Frequency Shift Keying, dan Phase Shift Keying.

# %% [markdown]
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/ASK1-a13caa66d0e0cd86e20aa7981a420d0b4e2dca4dccef4558265bfa4e1980292c.jpg)

# %% [markdown]
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/FSK1-6b03100104b70c223a48576f2c35d0082c36eb59f129ccdcf52b80305477f973.jpg)

# %% [markdown]
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/PSK1-09433a285e937f48892874bd64f13220231e512165fbdada901abe3e2cff2e71.jpg)

# %% [markdown]
# ## Coba identifikasi jenis modulasi apakah ini?

# %% [markdown]
# # 1
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/AM_76MHz_FFT-350ff76f6ab2a2c32872ef02a8773c31c7a2d7cf3060c239c10c96505bd7dd0c.gif)

# %% [markdown]
# # 2
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/FM_104MHz_FFT-f3ccb3e6723fa1f886bbaa587beade30071d44ab643c42a05bc0aba214873221.gif)

# %% [markdown]
# # 3
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/AMOOK_433MHz_FFT_HackRF-3ae400b540f3d95e7eea04c96fd05be06f9167824c964cbb4425fa6e237fb47c.gif)

# %% [markdown]
# ## Modulasi yang lebih kompleks
#
# ### Quadrature Amplitude Modulation (QAM)
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/QAM16-db8b95c2aafe8b12fb4189496fc0aa94d80595d8521f4ea1476663338c4e3b55.gif)

# %% [markdown]
# ## Aplikasi
# Dengan mengetahui karakteristik gelombang EM kita dapat meng-hack sebuah system seperti yang kita kehendaki
#
# Contoh menghack bel pintu wireless
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/doorbell_ext-dc081e49b0d36da422372d39e0ecb6ecdbdb335c04a78156b9cade6227ab8cb5.jpg)
#
# Dengan rangkaian elektronika
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/doorbell_int-42c4bdfe280113ebbe09c6a9a729f2e2e029915648d8868849bfb1e4520b343a.jpg)

# %% [markdown]
# Karakteristik gelombang EMnya dapat dilihat, saat tombol bel ditekan
#
# ![](https://www.elttam.com.au/assets/blog/2017-06-13-brief-sdr-and-rf-analysis/AMOOK_433MHz_FFT_HackRF-3ae400b540f3d95e7eea04c96fd05be06f9167824c964cbb4425fa6e237fb47c.gif)

# %%
#!/usr/bin/python
import sys
from rflib import *
import bitstring

baseFreq = 433920000 # 433.92 MHz
baudRate = 2960

key = '000101110111011101110111011100010111011100010111000100010111011101110111'
pad = '0000000000000000'

d = RfCat()
d.setMdmModulation(MOD_ASK_OOK) # Setting the modulation
d.setFreq(baseFreq)             # Setting the TX frequency
d.setMdmSyncMode(0)             # No sync mode
d.setMdmDRate(baudRate)         # The symbol rate
d.setMaxPower()                 # Max Power, YOLO!
#d.setPktPQT(0) # Preamble Quality Threshold

full_pwm = '{}{}'.format(key, pad)
rf_data = bitstring.BitArray(bin=full_pwm).tobytes() # Convert to bytes
d.makePktFLEN(len(rf_data))                          # Set the packet length in bytes
print "Transmitting key {}".format(rf_data.encode('hex'))
print "Packet length: " + str(len(rf_data))

d.RFxmit('\x00\x01\x00\x00') # TX synchronisation pulse
d.RFxmit(rf_data, repeat=30) # TX repeated packets

print "Done."
d.setModeIDLE()
# Out:
#   File "<ipython-input-3-b5216d449633>", line 23
#     print "Transmitting key {}".format(rf_data.encode('hex'))
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![](https://simpan.ugm.ac.id/index.php/apps/files_sharing/ajax/publicpreview.php?x=1920&y=619&a=true&file=lora2.png&t=YfkhpYaE88jSCeT&scalingup=0)
